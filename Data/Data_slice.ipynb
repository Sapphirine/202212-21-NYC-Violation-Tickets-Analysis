# %%
import pandas as pd
import mplleaflet
import mapclassify
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
import numpy as np

# Replace any number of spaces with just a single space
def refineSpaces(x):
    return x.replace('\s+', ' ', regex=True)

# Remove leading and trailing white space
def removeExcessWhitespace(x):
    return x.str.strip()

# Convert the string to uppercase
def toUpper(x):
    return x.str.upper()

# %%
df = pd.read_csv('/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/generated/nyc-merged-data-all.csv', low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0  Summons Number Plate ID Registration State Plate Type  \
# 0           0      1484697625   H73NYD                 NJ        PAS
# 1           1      1484697674  GJC9296                 NY        PAS
# 2           2      1484697686   M51PUV                 NJ        PAS
# 3           3      1484697698   H73NYD                 NJ        PAS
# 4           4      1484697728   M51PUV                 NJ        PAS
#
#    Issue Date  Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0  06/19/2022              63               SDN         JEEP              N
# 1  06/19/2022              63              SUBN        LEXUS              N
# 2  06/19/2022              63               SDN        HYUND              N
# 3  06/23/2022              63               NaN         JEEP              K
# 4  06/23/2022              63               NaN        HYUND              K
#
#    ...  REGION  POSTCODE         ID              HASH   zcta  bcode  note  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852861 entries, 0 to 852860
# Data columns (total 61 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Unnamed: 0                                     852861 non-null  int64
#  1   Summons Number                                 852861 non-null  int64
#  2   Plate ID                                       852854 non-null  object
#  3   Registration State                             852861 non-null  object
#  4   Plate Type                                     852861 non-null  object
#  5   Issue Date                                     852861 non-null  object
#  6   Violation Code                                 852861 non-null  int64
#  7   Vehicle Body Type                              850566 non-null  object
#  8   Vehicle Make                                   851526 non-null  object
# ...

# %%
df_1_12 = df.iloc[0:71072, :]

# %%
df_1_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_1_12.csv")

# %%
df_2_12 = df.iloc[71072:142144, :]

# %%
df_2_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_2_12.csv")

# %%
df_3_12 = df.iloc[142144:213216, :]
df_3_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_3_12.csv")

# %%
df_4_12 = df.iloc[213216:284288, :]
df_4_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_4_12.csv")

# %%
df_5_12 = df.iloc[284288:355360, :]
df_5_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_5_12.csv")

# %%
df_6_12 = df.iloc[355360:426432, :]
df_6_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_6_12.csv")

# %%
df_7_12 = df.iloc[426432:497504, :]
df_7_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_7_12.csv")

# %%
df_8_12 = df.iloc[497504:568576, :]
df_8_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_8_12.csv")

# %%
df_9_12 = df.iloc[568576:639648, :]
df_9_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_9_12.csv")

# %%
df_10_12 = df.iloc[639648:710720, :]
df_10_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_10_12.csv")

# %%
df_11_12 = df.iloc[710720:781792, :]
df_11_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_11_12.csv")

# %%
df_12_12 = df.iloc[781792:, :]
df_12_12.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/df_12_12.csv")

# %%
df_1_12['Issue Date'] = pd.to_datetime(df_1_12[IssueDate])
# Out:
#   Input In [5]
#     df_1_12['Issue Date'] = pd.to_datetime(df_1_12.'Issue Date')
#                                                    ^
# SyntaxError: invalid syntax

# %%
df = df.rename(columns={"Issue Date":"IssueDate"})

# %%
df.head()
# Out:
#    Unnamed: 0  Summons Number Plate ID Registration State Plate Type  \
# 0           0      1484697625   H73NYD                 NJ        PAS
# 1           1      1484697674  GJC9296                 NY        PAS
# 2           2      1484697686   M51PUV                 NJ        PAS
# 3           3      1484697698   H73NYD                 NJ        PAS
# 4           4      1484697728   M51PUV                 NJ        PAS
#
#     IssueDate  Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0  06/19/2022              63               SDN         JEEP              N
# 1  06/19/2022              63              SUBN        LEXUS              N
# 2  06/19/2022              63               SDN        HYUND              N
# 3  06/23/2022              63               NaN         JEEP              K
# 4  06/23/2022              63               NaN        HYUND              K
#
#    ...  REGION  POSTCODE         ID              HASH   zcta  bcode  note  \
# ...

# %%
df['IssueDate'] = pd.to_datetime(df.IssueDate)

# %%
df.head()
# Out:
#    Unnamed: 0  Summons Number Plate ID Registration State Plate Type  \
# 0           0      1484697625   H73NYD                 NJ        PAS
# 1           1      1484697674  GJC9296                 NY        PAS
# 2           2      1484697686   M51PUV                 NJ        PAS
# 3           3      1484697698   H73NYD                 NJ        PAS
# 4           4      1484697728   M51PUV                 NJ        PAS
#
#    IssueDate  Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0 2022-06-19              63               SDN         JEEP              N
# 1 2022-06-19              63              SUBN        LEXUS              N
# 2 2022-06-19              63               SDN        HYUND              N
# 3 2022-06-23              63               NaN         JEEP              K
# 4 2022-06-23              63               NaN        HYUND              K
#
#    ...  REGION  POSTCODE         ID              HASH   zcta  bcode  note  \
# ...

# %%
df['month'] = pd.DatetimeIndex(df['IssueDate']).month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852861 entries, 0 to 852860
# Data columns (total 62 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Unnamed: 0                                     852861 non-null  int64
#  1   Summons Number                                 852861 non-null  int64
#  2   Plate ID                                       852854 non-null  object
#  3   Registration State                             852861 non-null  object
#  4   Plate Type                                     852861 non-null  object
#  5   IssueDate                                      852861 non-null  datetime64[ns]
#  6   Violation Code                                 852861 non-null  int64
#  7   Vehicle Body Type                              850566 non-null  object
#  8   Vehicle Make                                   851526 non-null  object
# ...

# %%
df = df.rename(columns={"Issue Date":"IssueDate"})
df['IssueDate'] = pd.to_datetime(df.IssueDate)

# %%
df['month'] = pd.DatetimeIndex(df['IssueDate']).month

# %%
df.head()
# Out:
#    Unnamed: 0  Summons Number Plate ID Registration State Plate Type  \
# 0           0      1484697625   H73NYD                 NJ        PAS
# 1           1      1484697674  GJC9296                 NY        PAS
# 2           2      1484697686   M51PUV                 NJ        PAS
# 3           3      1484697698   H73NYD                 NJ        PAS
# 4           4      1484697728   M51PUV                 NJ        PAS
#
#    IssueDate  Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 0 2022-06-19              63               SDN         JEEP              N
# 1 2022-06-19              63              SUBN        LEXUS              N
# 2 2022-06-19              63               SDN        HYUND              N
# 3 2022-06-23              63               NaN         JEEP              K
# 4 2022-06-23              63               NaN        HYUND              K
#
#    ...  POSTCODE         ID              HASH   zcta  bcode  note  \
# ...

# %%
df['IssueDate'] = df['IssueDate'].dt.dayofweek

# %%
df['IssueDate']
# Out:
# 0         6
# 1         6
# 2         6
# 3         3
# 4         3
#          ..
# 852856    1
# 852857    4
# 852858    4
# 852859    3
# 852860    1
# Name: IssueDate, Length: 852861, dtype: int64

# %%
df["Violation Location"]
# Out:
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
#           ...
# 852856    75.0
# 852857    75.0
# 852858    75.0
# 852859    75.0
# 852860    75.0
# Name: Violation Location, Length: 852861, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852861 entries, 0 to 852860
# Data columns (total 62 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Unnamed: 0                                     852861 non-null  int64
#  1   Summons Number                                 852861 non-null  int64
#  2   Plate ID                                       852854 non-null  object
#  3   Registration State                             852861 non-null  object
#  4   Plate Type                                     852861 non-null  object
#  5   IssueDate                                      852861 non-null  int64
#  6   Violation Code                                 852861 non-null  int64
#  7   Vehicle Body Type                              850566 non-null  object
#  8   Vehicle Make                                   851526 non-null  object
# ...

# %%
July_df = df[df['month'] == 7]

# %%
July_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 292888 entries, 11 to 852842
# Data columns (total 62 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   Unnamed: 0                                     292888 non-null  int64
#  1   Summons Number                                 292888 non-null  int64
#  2   Plate ID                                       292885 non-null  object
#  3   Registration State                             292888 non-null  object
#  4   Plate Type                                     292888 non-null  object
#  5   IssueDate                                      292888 non-null  datetime64[ns]
#  6   Violation Code                                 292888 non-null  int64
#  7   Vehicle Body Type                              292106 non-null  object
#  8   Vehicle Make                                   292437 non-null  object
# ...

# %%
July_df.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/July_df.csv")

# %%
June_df.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/June_df.csv")

# %%
July_df = July_df[['Violation Location', 'Registration State', 'Violation Code',
        'Vehicle Body Type', 'Vehicle Make', 'Violation Time',
        'Violation County', 'Street Name', 'Vehicle Color', 'Median income (dollars); Estimate; Households',
        'IssueDate']]

# %%
July_df
# Out:
#         Unnamed: 0  Summons Number  Plate ID Registration State Plate Type  \
# 11              11      8995697969   KDU3450                 NY        PAS
# 21              21      1399430191   KVD7123                 NY        PAS
# 22              22      1399430373   KSU4912                 NY        PAS
# 23              23      1484697613   HGU1221                 NY        999
# 24              24      1484697649   KLT9191                 NY        PAS
# ...            ...             ...       ...                ...        ...
# 852793      852793      9002673437   GXF5220                 NY        PAS
# 852794      852794      9002673449  T748964C                 NY        OMT
# 852839      852839      1472022579   KWS7814                 NY        PAS
# 852840      852840      1487749466   JKE6089                 NY        PAS
# 852842      852842      1487749430   UTJ3992                 VA        PAS
#
#         IssueDate  Violation Code Vehicle Body Type Vehicle Make  \
# ...

# %%
July_df.to_csv("/Users/taolueyang/Documents/NY_Violations/New-York-City-Parking-Violations/Slice_data_random/July_df.csv")

# %%
Street_df = July_df["Violation County"]

# %%
Street_df
# Out:
# 11        NY
# 21        NY
# 22        NY
# 23        NY
# 24        NY
#           ..
# 852793     K
# 852794     K
# 852839    NY
# 852840     K
# 852842     K
# Name: Violation County, Length: 292888, dtype: object

# %%
County_number = July_df.groupby('Violation County').ngroup()

# %%
key = County_number.unique()

# %%
len(key)
# Out:
# 9

# %%
County_number
# Out:
# 11        4
# 21        4
# 22        4
# 23        4
# 24        4
#          ..
# 852793    2
# 852794    2
# 852839    4
# 852840    2
# 852842    2
# Length: 292888, dtype: int64

# %%
value = Street_df.unique()

# %%
value
# Out:
# array(['NY', 'K', 'Kings', nan, 'R', 'BX', 'Q', 'Bronx', 'Qns'],
#       dtype=object)

# %%
dic = {}

# %%
for i in range(len(key)):
    dic[value[i]] = key[i]

# %%
dic
# Out:
# {'NY': 4,
#  'K': 2,
#  'Kings': 3,
#  nan: -1,
#  'R': 7,
#  'BX': 0,
#  'Q': 5,
#  'Bronx': 1,
#  'Qns': 6}

# %%
dic["SOUTH ST"]
# Out:
# 3529

# %%
df = pd.DataFrame.from_dict(dic, orient="index")

# %%
df.to_csv("/Users/taolueyang/Documents/6893-22Fall-Group-22/Street_dic.csv")

# %%
dic = pd.read_csv("/Users/taolueyang/Documents/6893-22Fall-Group-22/Street_dic.csv")

# %%
dic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4257 entries, 0 to 4256
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StreetName  4257 non-null   object
#  1   StreetCode  4257 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 66.6+ KB

# %%
dic = dict(zip(dic.StreetCode, dic.StreetName))

# %%
dic[1755]
# Out:
# 'ELTON ST'

# %%
a = [1, 2, 3, "SOUTH ST", 5]

# %%
a[3] = dic[a[3]]

# %%
a
# Out:
# [1, 2, 3, 3529, 5]
